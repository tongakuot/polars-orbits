# %% [markdown]
# ## Importing Data Into Polars
#
# In this section, we'll learn how to import CSV, Excel (including multiple files and sheets) into `Polars`.
#
# We'll focus on `Polars` because of its speed and elegant syntax.

# %% [markdown]
# ## Load required libraries

# %%
# Import packages
import polars as pl
import polars.selectors as cs
import os 
import sys 
import glob

# Display my system version
print(f'My Python version is {sys.version};\nPolars version is {pl.__version__}')
# Out:
# My Python version is 3.12.4 (main, Jul  1 2024, 00:48:18) [Clang 15.0.0 (clang-1500.3.9.4)];
# Polars version is 1.8.2
# My Python version is 3.12.4 (main, Jul  1 2024, 00:48:18) [Clang 15.0.0 (clang-1500.3.9.4)];
# Polars version is 1.8.2

# %% [markdown]
# ## Importing CSV file

# %%
# Import South Sudan 2008 Census Data
file_path = '../00-data/ss_2008_census_data_raw.csv'
(
    pl.read_csv(
        file_path,
        # Ignoring error message
        ignore_errors=True
    )
)
# Out:
# shape: (453, 10)
# ┌─────────┬─────────┬─────────┬─────────┬───┬────────┬───────┬────────┬────────┐
# │ Region  ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age    ┆ Scale ┆ Units  ┆ 2008   │
# │ ---     ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name   ┆ ---   ┆ ---    ┆ ---    │
# │ str     ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---    ┆ str   ┆ str    ┆ i64    │
# │         ┆ str     ┆ ---     ┆ str     ┆   ┆ str    ┆       ┆        ┆        │
# │         ┆         ┆ str     ┆         ┆   ┆        ┆       ┆        ┆        │
# ╞═════════╪═════════╪═════════╪═════════╪═══╪════════╪═══════╪════════╪════════╡
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ Total  ┆ units ┆ Person ┆ 964353 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 0 to 4 ┆ units ┆ Person ┆ 150872 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 5 to 9 ┆ units ┆ Person ┆ 151467 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 10 to  ┆ units ┆ Person ┆ 126140 │
# │         ┆ Nile    ┆         ┆         ┆   ┆ 14     ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 15 to  ┆ units ┆ Person ┆ 103804 │
# │         ┆ Nile    ┆         ┆         ┆   ┆ 19     ┆       ┆ s      ┆        │
# │ …       ┆ …       ┆ …       ┆ …       ┆ … ┆ …      ┆ …     ┆ …      ┆ …      │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 60 to  ┆ units ┆ Person ┆ 5274   │
# │         ┆ Equator ┆         ┆         ┆   ┆ 64     ┆       ┆ s      ┆        │
# │         ┆ ia      ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 65+    ┆ units ┆ Person ┆ 8637   │
# │         ┆ Equator ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │         ┆ ia      ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ NA      ┆ NA      ┆ NA      ┆ NA      ┆ … ┆ NA     ┆ NA    ┆ NA     ┆ null   │
# │ Source: ┆ Nationa ┆ NA      ┆ NA      ┆ … ┆ NA     ┆ NA    ┆ NA     ┆ null   │
# │         ┆ l       ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ Bureau  ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ of Stat ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ istics, ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ …       ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ Downloa ┆ http:// ┆ NA      ┆ NA      ┆ … ┆ NA     ┆ NA    ┆ NA     ┆ null   │
# │ d URL:  ┆ southsu ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ dan.ope ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ ndatafo ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ ra…     ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# └─────────┴─────────┴─────────┴─────────┴───┴────────┴───────┴────────┴────────┘

# %%
# Import South Sudan 2008 Census Data
census_raw = (
    pl.read_csv(
        '../00-data/ss_2008_census_data_raw.csv',
        
        # Specifying missing values as 'NA'
        null_values='NA'
    )
)

# Inspect output
print(census_raw)
# Out:
# shape: (453, 10)
# ┌─────────┬─────────┬─────────┬─────────┬───┬────────┬───────┬────────┬────────┐
# │ Region  ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age    ┆ Scale ┆ Units  ┆ 2008   │
# │ ---     ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name   ┆ ---   ┆ ---    ┆ ---    │
# │ str     ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---    ┆ str   ┆ str    ┆ i64    │
# │         ┆ str     ┆ ---     ┆ str     ┆   ┆ str    ┆       ┆        ┆        │
# │         ┆         ┆ str     ┆         ┆   ┆        ┆       ┆        ┆        │
# ╞═════════╪═════════╪═════════╪═════════╪═══╪════════╪═══════╪════════╪════════╡
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ Total  ┆ units ┆ Person ┆ 964353 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 0 to 4 ┆ units ┆ Person ┆ 150872 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 5 to 9 ┆ units ┆ Person ┆ 151467 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 10 to  ┆ units ┆ Person ┆ 126140 │
# │         ┆ Nile    ┆         ┆         ┆   ┆ 14     ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 15 to  ┆ units ┆ Person ┆ 103804 │
# │         ┆ Nile    ┆         ┆         ┆   ┆ 19     ┆       ┆ s      ┆        │
# │ …       ┆ …       ┆ …       ┆ …       ┆ … ┆ …      ┆ …     ┆ …      ┆ …      │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 60 to  ┆ units ┆ Person ┆ 5274   │
# │         ┆ Equator ┆         ┆         ┆   ┆ 64     ┆       ┆ s      ┆        │
# │         ┆ ia      ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 65+    ┆ units ┆ Person ┆ 8637   │
# │         ┆ Equator ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │         ┆ ia      ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ null    ┆ null    ┆ null    ┆ null    ┆ … ┆ null   ┆ null  ┆ null   ┆ null   │
# │ Source: ┆ Nationa ┆ null    ┆ null    ┆ … ┆ null   ┆ null  ┆ null   ┆ null   │
# │         ┆ l       ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ Bureau  ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ of Stat ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ istics, ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ …       ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ Downloa ┆ http:// ┆ null    ┆ null    ┆ … ┆ null   ┆ null  ┆ null   ┆ null   │
# │ d URL:  ┆ southsu ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ dan.ope ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ ndatafo ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ ra…     ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# └─────────┴─────────┴─────────┴─────────┴───┴────────┴───────┴────────┴────────┘
# shape: (453, 10)
# ┌─────────┬─────────┬─────────┬─────────┬───┬────────┬───────┬────────┬────────┐
# │ Region  ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age    ┆ Scale ┆ Units  ┆ 2008   │
# │ ---     ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name   ┆ ---   ┆ ---    ┆ ---    │
# │ str     ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---    ┆ str   ┆ str    ┆ i64    │
# │         ┆ str     ┆ ---     ┆ str     ┆   ┆ str    ┆       ┆        ┆        │
# │         ┆         ┆ str     ┆         ┆   ┆        ┆       ┆        ┆        │
# ╞═════════╪═════════╪═════════╪═════════╪═══╪════════╪═══════╪════════╪════════╡
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ Total  ┆ units ┆ Person ┆ 964353 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 0 to 4 ┆ units ┆ Person ┆ 150872 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 5 to 9 ┆ units ┆ Person ┆ 151467 │
# │         ┆ Nile    ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 10 to  ┆ units ┆ Person ┆ 126140 │
# │         ┆ Nile    ┆         ┆         ┆   ┆ 14     ┆       ┆ s      ┆        │
# │ KN.A2   ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 15 to  ┆ units ┆ Person ┆ 103804 │
# │         ┆ Nile    ┆         ┆         ┆   ┆ 19     ┆       ┆ s      ┆        │
# │ …       ┆ …       ┆ …       ┆ …       ┆ … ┆ …      ┆ …     ┆ …      ┆ …      │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 60 to  ┆ units ┆ Person ┆ 5274   │
# │         ┆ Equator ┆         ┆         ┆   ┆ 64     ┆       ┆ s      ┆        │
# │         ┆ ia      ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 65+    ┆ units ┆ Person ┆ 8637   │
# │         ┆ Equator ┆         ┆         ┆   ┆        ┆       ┆ s      ┆        │
# │         ┆ ia      ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ null    ┆ null    ┆ null    ┆ null    ┆ … ┆ null   ┆ null  ┆ null   ┆ null   │
# │ Source: ┆ Nationa ┆ null    ┆ null    ┆ … ┆ null   ┆ null  ┆ null   ┆ null   │
# │         ┆ l       ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ Bureau  ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ of Stat ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ istics, ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ …       ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │ Downloa ┆ http:// ┆ null    ┆ null    ┆ … ┆ null   ┆ null  ┆ null   ┆ null   │
# │ d URL:  ┆ southsu ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ dan.ope ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ ndatafo ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# │         ┆ ra…     ┆         ┆         ┆   ┆        ┆       ┆        ┆        │
# └─────────┴─────────┴─────────┴─────────┴───┴────────┴───────┴────────┴────────┘

# %%
# Pull out the first 5 rows
print(census_raw.head(7))
# Out:
# shape: (7, 10)
# ┌────────┬─────────┬─────────┬─────────┬───┬─────────┬───────┬────────┬────────┐
# │ Region ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age     ┆ Scale ┆ Units  ┆ 2008   │
# │ ---    ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name    ┆ ---   ┆ ---    ┆ ---    │
# │ str    ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---     ┆ str   ┆ str    ┆ i64    │
# │        ┆ str     ┆ ---     ┆ str     ┆   ┆ str     ┆       ┆        ┆        │
# │        ┆         ┆ str     ┆         ┆   ┆         ┆       ┆        ┆        │
# ╞════════╪═════════╪═════════╪═════════╪═══╪═════════╪═══════╪════════╪════════╡
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ Total   ┆ units ┆ Person ┆ 964353 │
# │        ┆ Nile    ┆         ┆         ┆   ┆         ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 0 to 4  ┆ units ┆ Person ┆ 150872 │
# │        ┆ Nile    ┆         ┆         ┆   ┆         ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 5 to 9  ┆ units ┆ Person ┆ 151467 │
# │        ┆ Nile    ┆         ┆         ┆   ┆         ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 10 to   ┆ units ┆ Person ┆ 126140 │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 14      ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 15 to   ┆ units ┆ Person ┆ 103804 │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 19      ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 20 to   ┆ units ┆ Person ┆ 82588  │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 24      ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 25 to   ┆ units ┆ Person ┆ 76754  │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 29      ┆       ┆ s      ┆        │
# └────────┴─────────┴─────────┴─────────┴───┴─────────┴───────┴────────┴────────┘
# shape: (7, 10)
# ┌────────┬─────────┬─────────┬─────────┬───┬─────────┬───────┬────────┬────────┐
# │ Region ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age     ┆ Scale ┆ Units  ┆ 2008   │
# │ ---    ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name    ┆ ---   ┆ ---    ┆ ---    │
# │ str    ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---     ┆ str   ┆ str    ┆ i64    │
# │        ┆ str     ┆ ---     ┆ str     ┆   ┆ str     ┆       ┆        ┆        │
# │        ┆         ┆ str     ┆         ┆   ┆         ┆       ┆        ┆        │
# ╞════════╪═════════╪═════════╪═════════╪═══╪═════════╪═══════╪════════╪════════╡
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ Total   ┆ units ┆ Person ┆ 964353 │
# │        ┆ Nile    ┆         ┆         ┆   ┆         ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 0 to 4  ┆ units ┆ Person ┆ 150872 │
# │        ┆ Nile    ┆         ┆         ┆   ┆         ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 5 to 9  ┆ units ┆ Person ┆ 151467 │
# │        ┆ Nile    ┆         ┆         ┆   ┆         ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 10 to   ┆ units ┆ Person ┆ 126140 │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 14      ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 15 to   ┆ units ┆ Person ┆ 103804 │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 19      ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 20 to   ┆ units ┆ Person ┆ 82588  │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 24      ┆       ┆ s      ┆        │
# │ KN.A2  ┆ Upper   ┆ SS-NU   ┆ KN.B2   ┆ … ┆ 25 to   ┆ units ┆ Person ┆ 76754  │
# │        ┆ Nile    ┆         ┆         ┆   ┆ 29      ┆       ┆ s      ┆        │
# └────────┴─────────┴─────────┴─────────┴───┴─────────┴───────┴────────┴────────┘

# %%
# Pull out the last 5 rows
print(census_raw.tail())
# Out:
# shape: (5, 10)
# ┌─────────┬─────────┬─────────┬─────────┬───┬─────────┬───────┬─────────┬──────┐
# │ Region  ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age     ┆ Scale ┆ Units   ┆ 2008 │
# │ ---     ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name    ┆ ---   ┆ ---     ┆ ---  │
# │ str     ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---     ┆ str   ┆ str     ┆ i64  │
# │         ┆ str     ┆ ---     ┆ str     ┆   ┆ str     ┆       ┆         ┆      │
# │         ┆         ┆ str     ┆         ┆   ┆         ┆       ┆         ┆      │
# ╞═════════╪═════════╪═════════╪═════════╪═══╪═════════╪═══════╪═════════╪══════╡
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 60 to   ┆ units ┆ Persons ┆ 5274 │
# │         ┆ Equator ┆         ┆         ┆   ┆ 64      ┆       ┆         ┆      │
# │         ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 65+     ┆ units ┆ Persons ┆ 8637 │
# │         ┆ Equator ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │ null    ┆ null    ┆ null    ┆ null    ┆ … ┆ null    ┆ null  ┆ null    ┆ null │
# │ Source: ┆ Nationa ┆ null    ┆ null    ┆ … ┆ null    ┆ null  ┆ null    ┆ null │
# │         ┆ l       ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ Bureau  ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ of Stat ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ istics, ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ …       ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │ Downloa ┆ http:// ┆ null    ┆ null    ┆ … ┆ null    ┆ null  ┆ null    ┆ null │
# │ d URL:  ┆ southsu ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ dan.ope ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ ndatafo ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ ra…     ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# └─────────┴─────────┴─────────┴─────────┴───┴─────────┴───────┴─────────┴──────┘
# shape: (5, 10)
# ┌─────────┬─────────┬─────────┬─────────┬───┬─────────┬───────┬─────────┬──────┐
# │ Region  ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age     ┆ Scale ┆ Units   ┆ 2008 │
# │ ---     ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name    ┆ ---   ┆ ---     ┆ ---  │
# │ str     ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---     ┆ str   ┆ str     ┆ i64  │
# │         ┆ str     ┆ ---     ┆ str     ┆   ┆ str     ┆       ┆         ┆      │
# │         ┆         ┆ str     ┆         ┆   ┆         ┆       ┆         ┆      │
# ╞═════════╪═════════╪═════════╪═════════╪═══╪═════════╪═══════╪═════════╪══════╡
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 60 to   ┆ units ┆ Persons ┆ 5274 │
# │         ┆ Equator ┆         ┆         ┆   ┆ 64      ┆       ┆         ┆      │
# │         ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │ KN.A11  ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 65+     ┆ units ┆ Persons ┆ 8637 │
# │         ┆ Equator ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │ null    ┆ null    ┆ null    ┆ null    ┆ … ┆ null    ┆ null  ┆ null    ┆ null │
# │ Source: ┆ Nationa ┆ null    ┆ null    ┆ … ┆ null    ┆ null  ┆ null    ┆ null │
# │         ┆ l       ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ Bureau  ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ of Stat ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ istics, ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ …       ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │ Downloa ┆ http:// ┆ null    ┆ null    ┆ … ┆ null    ┆ null  ┆ null    ┆ null │
# │ d URL:  ┆ southsu ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ dan.ope ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ ndatafo ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# │         ┆ ra…     ┆         ┆         ┆   ┆         ┆       ┆         ┆      │
# └─────────┴─────────┴─────────┴─────────┴───┴─────────┴───────┴─────────┴──────┘

# %%
# Pull out sample rows
print(census_raw.sample(7))
# Out:
# shape: (7, 10)
# ┌────────┬─────────┬─────────┬─────────┬───┬─────────┬───────┬─────────┬───────┐
# │ Region ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age     ┆ Scale ┆ Units   ┆ 2008  │
# │ ---    ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name    ┆ ---   ┆ ---     ┆ ---   │
# │ str    ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---     ┆ str   ┆ str     ┆ i64   │
# │        ┆ str     ┆ ---     ┆ str     ┆   ┆ str     ┆       ┆         ┆       │
# │        ┆         ┆ str     ┆         ┆   ┆         ┆       ┆         ┆       │
# ╞════════╪═════════╪═════════╪═════════╪═══╪═════════╪═══════╪═════════╪═══════╡
# │ KN.A11 ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 10 to   ┆ units ┆ Persons ┆ 61423 │
# │        ┆ Equator ┆         ┆         ┆   ┆ 14      ┆       ┆         ┆       │
# │        ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A4  ┆ Unity   ┆ SS-UY   ┆ KN.B5   ┆ … ┆ 55 to   ┆ units ┆ Persons ┆ 4497  │
# │        ┆         ┆         ┆         ┆   ┆ 59      ┆       ┆         ┆       │
# │ KN.A4  ┆ Unity   ┆ SS-UY   ┆ KN.B2   ┆ … ┆ 50 to   ┆ units ┆ Persons ┆ 12904 │
# │        ┆         ┆         ┆         ┆   ┆ 54      ┆       ┆         ┆       │
# │ KN.A10 ┆ Central ┆ SS-EC   ┆ KN.B5   ┆ … ┆ 35 to   ┆ units ┆ Persons ┆ 35613 │
# │        ┆ Equator ┆         ┆         ┆   ┆ 39      ┆       ┆         ┆       │
# │        ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A6  ┆ Norther ┆ SS-BN   ┆ KN.B5   ┆ … ┆ 35 to   ┆ units ┆ Persons ┆ 19371 │
# │        ┆ n Bahr  ┆         ┆         ┆   ┆ 39      ┆       ┆         ┆       │
# │        ┆ el      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │        ┆ Ghazal  ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A7  ┆ Western ┆ SS-BW   ┆ KN.B2   ┆ … ┆ 50 to   ┆ units ┆ Persons ┆ 7390  │
# │        ┆ Bahr el ┆         ┆         ┆   ┆ 54      ┆       ┆         ┆       │
# │        ┆ Ghazal  ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A6  ┆ Norther ┆ SS-BN   ┆ KN.B5   ┆ … ┆ 30 to   ┆ units ┆ Persons ┆ 18761 │
# │        ┆ n Bahr  ┆         ┆         ┆   ┆ 34      ┆       ┆         ┆       │
# │        ┆ el      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │        ┆ Ghazal  ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# └────────┴─────────┴─────────┴─────────┴───┴─────────┴───────┴─────────┴───────┘
# shape: (7, 10)
# ┌────────┬─────────┬─────────┬─────────┬───┬─────────┬───────┬─────────┬───────┐
# │ Region ┆ Region  ┆ Region  ┆ Variabl ┆ … ┆ Age     ┆ Scale ┆ Units   ┆ 2008  │
# │ ---    ┆ Name    ┆ - Regio ┆ e       ┆   ┆ Name    ┆ ---   ┆ ---     ┆ ---   │
# │ str    ┆ ---     ┆ nId     ┆ ---     ┆   ┆ ---     ┆ str   ┆ str     ┆ i64   │
# │        ┆ str     ┆ ---     ┆ str     ┆   ┆ str     ┆       ┆         ┆       │
# │        ┆         ┆ str     ┆         ┆   ┆         ┆       ┆         ┆       │
# ╞════════╪═════════╪═════════╪═════════╪═══╪═════════╪═══════╪═════════╪═══════╡
# │ KN.A11 ┆ Eastern ┆ SS-EE   ┆ KN.B8   ┆ … ┆ 10 to   ┆ units ┆ Persons ┆ 61423 │
# │        ┆ Equator ┆         ┆         ┆   ┆ 14      ┆       ┆         ┆       │
# │        ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A4  ┆ Unity   ┆ SS-UY   ┆ KN.B5   ┆ … ┆ 55 to   ┆ units ┆ Persons ┆ 4497  │
# │        ┆         ┆         ┆         ┆   ┆ 59      ┆       ┆         ┆       │
# │ KN.A4  ┆ Unity   ┆ SS-UY   ┆ KN.B2   ┆ … ┆ 50 to   ┆ units ┆ Persons ┆ 12904 │
# │        ┆         ┆         ┆         ┆   ┆ 54      ┆       ┆         ┆       │
# │ KN.A10 ┆ Central ┆ SS-EC   ┆ KN.B5   ┆ … ┆ 35 to   ┆ units ┆ Persons ┆ 35613 │
# │        ┆ Equator ┆         ┆         ┆   ┆ 39      ┆       ┆         ┆       │
# │        ┆ ia      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A6  ┆ Norther ┆ SS-BN   ┆ KN.B5   ┆ … ┆ 35 to   ┆ units ┆ Persons ┆ 19371 │
# │        ┆ n Bahr  ┆         ┆         ┆   ┆ 39      ┆       ┆         ┆       │
# │        ┆ el      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │        ┆ Ghazal  ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A7  ┆ Western ┆ SS-BW   ┆ KN.B2   ┆ … ┆ 50 to   ┆ units ┆ Persons ┆ 7390  │
# │        ┆ Bahr el ┆         ┆         ┆   ┆ 54      ┆       ┆         ┆       │
# │        ┆ Ghazal  ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │ KN.A6  ┆ Norther ┆ SS-BN   ┆ KN.B5   ┆ … ┆ 30 to   ┆ units ┆ Persons ┆ 18761 │
# │        ┆ n Bahr  ┆         ┆         ┆   ┆ 34      ┆       ┆         ┆       │
# │        ┆ el      ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# │        ┆ Ghazal  ┆         ┆         ┆   ┆         ┆       ┆         ┆       │
# └────────┴─────────┴─────────┴─────────┴───┴─────────┴───────┴─────────┴───────┘

# %%
# Print out the columns with their data types
census_raw.glimpse()
# Out:
# Rows: 453
# Columns: 10
# $ Region            <str> 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2'
# $ Region Name       <str> 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile'
# $ Region - RegionId <str> 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU'
# $ Variable          <str> 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2'
# $ Variable Name     <str> 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)'
# $ Age               <str> 'KN.C1', 'KN.C2', 'KN.C3', 'KN.C4', 'KN.C5', 'KN.C6', 'KN.C7', 'KN.C8', 'KN.C9', 'KN.C10'
# $ Age Name          <str> 'Total', '0 to 4', '5 to 9', '10 to 14', '15 to 19', '20 to 24', '25 to 29', '30 to 34', '35 to 39', '40 to 44'
# $ Scale             <str> 'units', 'units', 'units', 'units', 'units', 'units', 'units', 'units', 'units', 'units'
# $ Units             <str> 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons'
# $ 2008              <i64> 964353, 150872, 151467, 126140, 103804, 82588, 76754, 63134, 56806, 42139
#
# Rows: 453
# Columns: 10
# $ Region            <str> 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2', 'KN.A2'
# $ Region Name       <str> 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile', 'Upper Nile'
# $ Region - RegionId <str> 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU', 'SS-NU'
# $ Variable          <str> 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2', 'KN.B2'
# $ Variable Name     <str> 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)', 'Population, Total (Number)'
# $ Age               <str> 'KN.C1', 'KN.C2', 'KN.C3', 'KN.C4', 'KN.C5', 'KN.C6', 'KN.C7', 'KN.C8', 'KN.C9', 'KN.C10'
# $ Age Name          <str> 'Total', '0 to 4', '5 to 9', '10 to 14', '15 to 19', '20 to 24', '25 to 29', '30 to 34', '35 to 39', '40 to 44'
# $ Scale             <str> 'units', 'units', 'units', 'units', 'units', 'units', 'units', 'units', 'units', 'units'
# $ Units             <str> 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons', 'Persons'
# $ 2008              <i64> 964353, 150872, 151467, 126140, 103804, 82588, 76754, 63134, 56806, 42139

# %%
census_raw.columns
# Out:
# ['Region',
#  'Region Name',
#  'Region - RegionId',
#  'Variable',
#  'Variable Name',
#  'Age',
#  'Age Name',
#  'Scale',
#  'Units',
#  '2008']

# %%
# Import data by specifying columns of interest
census_raw2 =(
    pl.read_csv(
        path,
        null_values='NA',
        columns=['Region Name', 'Variable Name', 'Age Name', '2008']
    )
)

print(census_raw2.sample(15))
# Out:
# shape: (15, 4)
# ┌─────────────────────────┬─────────────────────────────┬──────────┬────────┐
# │ Region Name             ┆ Variable Name               ┆ Age Name ┆ 2008   │
# │ ---                     ┆ ---                         ┆ ---      ┆ ---    │
# │ str                     ┆ str                         ┆ str      ┆ i64    │
# ╞═════════════════════════╪═════════════════════════════╪══════════╪════════╡
# │ Northern Bahr el Ghazal ┆ Population, Total (Number)  ┆ 60 to 64 ┆ 11636  │
# │ Upper Nile              ┆ Population, Male (Number)   ┆ 40 to 44 ┆ 22290  │
# │ Unity                   ┆ Population, Female (Number) ┆ 20 to 24 ┆ 25687  │
# │ Central Equatoria       ┆ Population, Female (Number) ┆ 50 to 54 ┆ 11201  │
# │ Warrap                  ┆ Population, Female (Number) ┆ 55 to 59 ┆ 7015   │
# │ …                       ┆ …                           ┆ …        ┆ …      │
# │ Eastern Equatoria       ┆ Population, Female (Number) ┆ 30 to 34 ┆ 30734  │
# │ Northern Bahr el Ghazal ┆ Population, Female (Number) ┆ 15 to 19 ┆ 32093  │
# │ Western Equatoria       ┆ Population, Total (Number)  ┆ 20 to 24 ┆ 61278  │
# │ Lakes                   ┆ Population, Total (Number)  ┆ 40 to 44 ┆ 29718  │
# │ Central Equatoria       ┆ Population, Total (Number)  ┆ 5 to 9   ┆ 161582 │
# └─────────────────────────┴─────────────────────────────┴──────────┴────────┘
# shape: (15, 4)
# ┌─────────────────────────┬─────────────────────────────┬──────────┬────────┐
# │ Region Name             ┆ Variable Name               ┆ Age Name ┆ 2008   │
# │ ---                     ┆ ---                         ┆ ---      ┆ ---    │
# │ str                     ┆ str                         ┆ str      ┆ i64    │
# ╞═════════════════════════╪═════════════════════════════╪══════════╪════════╡
# │ Northern Bahr el Ghazal ┆ Population, Total (Number)  ┆ 60 to 64 ┆ 11636  │
# │ Upper Nile              ┆ Population, Male (Number)   ┆ 40 to 44 ┆ 22290  │
# │ Unity                   ┆ Population, Female (Number) ┆ 20 to 24 ┆ 25687  │
# │ Central Equatoria       ┆ Population, Female (Number) ┆ 50 to 54 ┆ 11201  │
# │ Warrap                  ┆ Population, Female (Number) ┆ 55 to 59 ┆ 7015   │
# │ …                       ┆ …                           ┆ …        ┆ …      │
# │ Eastern Equatoria       ┆ Population, Female (Number) ┆ 30 to 34 ┆ 30734  │
# │ Northern Bahr el Ghazal ┆ Population, Female (Number) ┆ 15 to 19 ┆ 32093  │
# │ Western Equatoria       ┆ Population, Total (Number)  ┆ 20 to 24 ┆ 61278  │
# │ Lakes                   ┆ Population, Total (Number)  ┆ 40 to 44 ┆ 29718  │
# │ Central Equatoria       ┆ Population, Total (Number)  ┆ 5 to 9   ┆ 161582 │
# └─────────────────────────┴─────────────────────────────┴──────────┴────────┘

# %%
print(
    census_raw
    .select(cs.ends_with('Name'), '2008')
)
# Out:
# shape: (453, 4)
# ┌─────────────────────────────┬────────────────────────────┬──────────┬────────┐
# │ Region Name                 ┆ Variable Name              ┆ Age Name ┆ 2008   │
# │ ---                         ┆ ---                        ┆ ---      ┆ ---    │
# │ str                         ┆ str                        ┆ str      ┆ i64    │
# ╞═════════════════════════════╪════════════════════════════╪══════════╪════════╡
# │ Upper Nile                  ┆ Population, Total (Number) ┆ Total    ┆ 964353 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 0 to 4   ┆ 150872 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 5 to 9   ┆ 151467 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 10 to 14 ┆ 126140 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 15 to 19 ┆ 103804 │
# │ …                           ┆ …                          ┆ …        ┆ …      │
# │ Eastern Equatoria           ┆ Population, Female         ┆ 60 to 64 ┆ 5274   │
# │                             ┆ (Number)                   ┆          ┆        │
# │ Eastern Equatoria           ┆ Population, Female         ┆ 65+      ┆ 8637   │
# │                             ┆ (Number)                   ┆          ┆        │
# │ null                        ┆ null                       ┆ null     ┆ null   │
# │ National Bureau of          ┆ null                       ┆ null     ┆ null   │
# │ Statistics,…                ┆                            ┆          ┆        │
# │ http://southsudan.opendataf ┆ null                       ┆ null     ┆ null   │
# │ ora…                        ┆                            ┆          ┆        │
# └─────────────────────────────┴────────────────────────────┴──────────┴────────┘
# shape: (453, 4)
# ┌─────────────────────────────┬────────────────────────────┬──────────┬────────┐
# │ Region Name                 ┆ Variable Name              ┆ Age Name ┆ 2008   │
# │ ---                         ┆ ---                        ┆ ---      ┆ ---    │
# │ str                         ┆ str                        ┆ str      ┆ i64    │
# ╞═════════════════════════════╪════════════════════════════╪══════════╪════════╡
# │ Upper Nile                  ┆ Population, Total (Number) ┆ Total    ┆ 964353 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 0 to 4   ┆ 150872 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 5 to 9   ┆ 151467 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 10 to 14 ┆ 126140 │
# │ Upper Nile                  ┆ Population, Total (Number) ┆ 15 to 19 ┆ 103804 │
# │ …                           ┆ …                          ┆ …        ┆ …      │
# │ Eastern Equatoria           ┆ Population, Female         ┆ 60 to 64 ┆ 5274   │
# │                             ┆ (Number)                   ┆          ┆        │
# │ Eastern Equatoria           ┆ Population, Female         ┆ 65+      ┆ 8637   │
# │                             ┆ (Number)                   ┆          ┆        │
# │ null                        ┆ null                       ┆ null     ┆ null   │
# │ National Bureau of          ┆ null                       ┆ null     ┆ null   │
# │ Statistics,…                ┆                            ┆          ┆        │
# │ http://southsudan.opendataf ┆ null                       ┆ null     ┆ null   │
# │ ora…                        ┆                            ┆          ┆        │
# └─────────────────────────────┴────────────────────────────┴──────────┴────────┘
